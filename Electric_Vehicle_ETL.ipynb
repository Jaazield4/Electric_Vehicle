# %% [markdown]
# # Electric Vehicle Sales Data

# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Load in the data
raw_data = pd.read_csv('Resources/Electric_Vehicle_Population_Data.csv')

# View the data
raw_data.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EB4L     Yakima     Yakima    WA      98908.0        2020  TESLA
# 1  5YJ3E1EA7K  San Diego  San Diego    CA      92101.0        2019  TESLA
# 2  7JRBR0FL9M       Lane     Eugene    OR      97404.0        2021  VOLVO
# 3  5YJXCBE21K     Yakima     Yakima    WA      98908.0        2019  TESLA
# 4  5UXKT0C5XH  Snohomish    Bothell    WA      98021.0        2017    BMW
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL 3          Battery Electric Vehicle (BEV)
# 1  MODEL 3          Battery Electric Vehicle (BEV)
# 2      S60  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  MODEL X          Battery Electric Vehicle (BEV)
# 4       X5  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             322
# 1           Clean Alternative Fuel Vehicle Eligible             220
# 2             Not eligible due to low battery range              22
# 3           Clean Alternative Fuel Vehicle Eligible             289
# 4             Not eligible due to low battery range              14
#
#    Base MSRP  Legislative District  DOL Vehicle ID      Vehicle Location  \
# 0          0                  14.0       127175366   -120.56916 46.58514
# 1          0                   NaN       266614659   -117.16171 32.71568
# 2          0                   NaN       144502018   -123.12802 44.09573
# 3          0                  14.0       477039944   -120.56916 46.58514
# 4          0                   1.0       106314946    -122.18384 47.8031
#
#     Latitude        Electric Utility  2020 Census Tract
# 0 -120.56916              PACIFICORP       5.307700e+10
# 1 -117.16171                     NaN       6.073005e+09
# 2        NaN                     NaN       4.103900e+10
# 3        NaN              PACIFICORP       5.307700e+10
# 4        NaN  PUGET SOUND ENERGY INC       5.306105e+10

# %%
# View the data type of every column
raw_data.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# Latitude                                             float64
# Electric Utility                                      object
# 2020 Census Tract                                    float64
# dtype: object

# %%
# Rename Columns
renamed_df = raw_data.rename(columns = {'VIN (1-10)' : 'VIN', 'Postal Code' : 'ZIP', 'Model Year' : 'Model_Year', 
                                       'Electric Vehicle Type': 'Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility' :
                                       'CAFV_Eligibility', 'Electric Range' : 'Range', 'Base MSRP' : 'Base_MSRP', 
                                       'Vehicle Location' : 'Vehicle_Location'})

# Keep only necessary columns
renamed_df = renamed_df[['VIN', 'County', 'City', 'State', 'ZIP', 'Model_Year', 'Make', 'Model', 'Type', 'CAFV_Eligibility',
                        'Range', 'Base_MSRP', 'Vehicle_Location']]

# View the data
renamed_df.head()
# Out:
#           VIN     County       City State      ZIP  Model_Year   Make  \
# 0  5YJ3E1EB4L     Yakima     Yakima    WA  98908.0        2020  TESLA
# 1  5YJ3E1EA7K  San Diego  San Diego    CA  92101.0        2019  TESLA
# 2  7JRBR0FL9M       Lane     Eugene    OR  97404.0        2021  VOLVO
# 3  5YJXCBE21K     Yakima     Yakima    WA  98908.0        2019  TESLA
# 4  5UXKT0C5XH  Snohomish    Bothell    WA  98021.0        2017    BMW
#
#      Model                                    Type  \
# 0  MODEL 3          Battery Electric Vehicle (BEV)
# 1  MODEL 3          Battery Electric Vehicle (BEV)
# 2      S60  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  MODEL X          Battery Electric Vehicle (BEV)
# 4       X5  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                           CAFV_Eligibility  Range  Base_MSRP  \
# 0  Clean Alternative Fuel Vehicle Eligible    322          0
# 1  Clean Alternative Fuel Vehicle Eligible    220          0
# 2    Not eligible due to low battery range     22          0
# 3  Clean Alternative Fuel Vehicle Eligible    289          0
# 4    Not eligible due to low battery range     14          0
#
#        Vehicle_Location
# 0   -120.56916 46.58514
# 1   -117.16171 32.71568
# 2   -123.12802 44.09573
# 3   -120.56916 46.58514
# 4    -122.18384 47.8031

# %%
# Check how many rows there are
renamed_df.count()
# Out:
# VIN                 124716
# County              124714
# City                124714
# State               124716
# ZIP                 124714
# Model_Year          124716
# Make                124716
# Model               124535
# Type                124716
# CAFV_Eligibility    124716
# Range               124716
# Base_MSRP           124716
# Vehicle_Location    124687
# dtype: int64

# %%
# Check for null values
renamed_df.isnull().sum()
# Out:
# VIN                   0
# County                2
# City                  2
# State                 0
# ZIP                   2
# Model_Year            0
# Make                  0
# Model               181
# Type                  0
# CAFV_Eligibility      0
# Range                 0
# Base_MSRP             0
# Vehicle_Location     29
# dtype: int64

# %%
# Drop any null values
full_raw_data = renamed_df.dropna()

# Check amount of null values per column
full_raw_data.isnull().sum()
# Out:
# VIN                 0
# County              0
# City                0
# State               0
# ZIP                 0
# Model_Year          0
# Make                0
# Model               0
# Type                0
# CAFV_Eligibility    0
# Range               0
# Base_MSRP           0
# Vehicle_Location    0
# dtype: int64

# %%
# Check unique values for column 'Electric Vehicle Type'
full_raw_data.Type.unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
# Change the name of values for Type column for easier read
full_raw_data['Type'] = full_raw_data['Type'].replace('Battery Electric Vehicle (BEV)', 'EV')
full_raw_data['Type'] = full_raw_data['Type'].replace('Plug-in Hybrid Electric Vehicle (PHEV)', 'Hybrid')

# Recheck the unique values
full_raw_data.Type.unique()
# Out:
# C:\Users\19565\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\19565\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# array(['EV', 'Hybrid'], dtype=object)

# %%
# View the data
full_raw_data.head()
# Out:
#           VIN     County       City State      ZIP  Model_Year   Make  \
# 0  5YJ3E1EB4L     Yakima     Yakima    WA  98908.0        2020  TESLA
# 1  5YJ3E1EA7K  San Diego  San Diego    CA  92101.0        2019  TESLA
# 2  7JRBR0FL9M       Lane     Eugene    OR  97404.0        2021  VOLVO
# 3  5YJXCBE21K     Yakima     Yakima    WA  98908.0        2019  TESLA
# 4  5UXKT0C5XH  Snohomish    Bothell    WA  98021.0        2017    BMW
#
#      Model    Type                         CAFV_Eligibility  Range  Base_MSRP  \
# 0  MODEL 3      EV  Clean Alternative Fuel Vehicle Eligible    322          0
# 1  MODEL 3      EV  Clean Alternative Fuel Vehicle Eligible    220          0
# 2      S60  Hybrid    Not eligible due to low battery range     22          0
# 3  MODEL X      EV  Clean Alternative Fuel Vehicle Eligible    289          0
# 4       X5  Hybrid    Not eligible due to low battery range     14          0
#
#        Vehicle_Location
# 0   -120.56916 46.58514
# 1   -117.16171 32.71568
# 2   -123.12802 44.09573
# 3   -120.56916 46.58514
# 4    -122.18384 47.8031

# %%
# Separate Vehicle_Location into multiple Latitude and Longitude
full_raw_data[['Space', 'Latitude', 'Longitude']] = full_raw_data.Vehicle_Location.str.split(' ', expand = True)
full_raw_data.head()
# Out:
# C:\Users\19565\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#           VIN     County       City State      ZIP  Model_Year   Make  \
# 0  5YJ3E1EB4L     Yakima     Yakima    WA  98908.0        2020  TESLA
# 1  5YJ3E1EA7K  San Diego  San Diego    CA  92101.0        2019  TESLA
# 2  7JRBR0FL9M       Lane     Eugene    OR  97404.0        2021  VOLVO
# 3  5YJXCBE21K     Yakima     Yakima    WA  98908.0        2019  TESLA
# 4  5UXKT0C5XH  Snohomish    Bothell    WA  98021.0        2017    BMW
#
#      Model    Type                         CAFV_Eligibility  Range  Base_MSRP  \
# 0  MODEL 3      EV  Clean Alternative Fuel Vehicle Eligible    322          0
# 1  MODEL 3      EV  Clean Alternative Fuel Vehicle Eligible    220          0
# 2      S60  Hybrid    Not eligible due to low battery range     22          0
# 3  MODEL X      EV  Clean Alternative Fuel Vehicle Eligible    289          0
# 4       X5  Hybrid    Not eligible due to low battery range     14          0
#
#        Vehicle_Location Space    Latitude Longitude
# 0   -120.56916 46.58514        -120.56916  46.58514
# 1   -117.16171 32.71568        -117.16171  32.71568
# 2   -123.12802 44.09573        -123.12802  44.09573
# 3   -120.56916 46.58514        -120.56916  46.58514
# 4    -122.18384 47.8031        -122.18384   47.8031

# %%
# Delete Columns that are no longer needed
final_columns_data = full_raw_data.drop(columns = ['Space', 'Vehicle_Location'])

# View data
final_columns_data.head()
# Out:
#           VIN     County       City State      ZIP  Model_Year   Make  \
# 0  5YJ3E1EB4L     Yakima     Yakima    WA  98908.0        2020  TESLA
# 1  5YJ3E1EA7K  San Diego  San Diego    CA  92101.0        2019  TESLA
# 2  7JRBR0FL9M       Lane     Eugene    OR  97404.0        2021  VOLVO
# 3  5YJXCBE21K     Yakima     Yakima    WA  98908.0        2019  TESLA
# 4  5UXKT0C5XH  Snohomish    Bothell    WA  98021.0        2017    BMW
#
#      Model    Type                         CAFV_Eligibility  Range  Base_MSRP  \
# 0  MODEL 3      EV  Clean Alternative Fuel Vehicle Eligible    322          0
# 1  MODEL 3      EV  Clean Alternative Fuel Vehicle Eligible    220          0
# 2      S60  Hybrid    Not eligible due to low battery range     22          0
# 3  MODEL X      EV  Clean Alternative Fuel Vehicle Eligible    289          0
# 4       X5  Hybrid    Not eligible due to low battery range     14          0
#
#      Latitude Longitude
# 0  -120.56916  46.58514
# 1  -117.16171  32.71568
# 2  -123.12802  44.09573
# 3  -120.56916  46.58514
# 4  -122.18384   47.8031

# %%
# Check unique values for column 'CAFV_Elibility'
final_columns_data.CAFV_Eligibility.unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %%
# Change Values of "CAFV_ELigibility" for easier read
final_columns_data['CAFV_Eligibility'] = final_columns_data['CAFV_Eligibility'].replace('Clean Alternative Fuel Vehicle Eligible'
                                                                                       , 'Eligible')
final_columns_data['CAFV_Eligibility'] = final_columns_data['CAFV_Eligibility'].replace('Not eligible due to low battery range'
                                                                                       , 'Not Eligible')
final_columns_data['CAFV_Eligibility'] = final_columns_data['CAFV_Eligibility'].replace('Eligibility unknown as battery range has not been researched'
                                                                                       , 'Unknown')

# Recheck unique values for column 'CAFV_Elibility'
final_columns_data.CAFV_Eligibility.unique()
# Out:
# array(['Eligible', 'Not Eligible', 'Unknown'], dtype=object)

# %%
EV_Sales_data = final_columns_data

# Download to csv
EV_Sales_data.to_csv('Resources/EV_sales_data.csv')
